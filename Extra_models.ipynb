# %% [markdown]
# #Imports and data prepairing

# %%
import numpy as np
import pandas as pd
import warnings
from sklearn.model_selection import train_test_split
from scipy.sparse import csr_matrix
from sklearn.metrics import ndcg_score
from sklearn.neighbors import NearestNeighbors
from scipy.spatial.distance import correlation
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler

warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/drive')
path = "/drive/MyDrive/DS/RecSys"

# !mkdir data
# !cp -a /$path/. data
# Out:
# Mounted at /drive

# %%
!7z e "data/train.csv.7z"
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 106420688 bytes (102 MiB)
#
# Extracting archive: data/train.csv.7z
# --
# Path = data/train.csv.7z
# Type = 7z
# Physical Size = 106420688
# Headers Size = 122
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       971675848
# Compressed: 106420688

# %%
data = pd.read_csv("train.csv")
data.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target
# 0              Explore  online-playlist       1
# 1  Local playlist more   local-playlist       1
# 2  Local playlist more   local-playlist       1
# 3  Local playlist more   local-playlist       1
# 4              Explore  online-playlist       1

# %% [markdown]
# #Исследование Моделей

# %% [markdown]
# Попробуем 3 метод(описан в другом ноутбуке). Если коротко, то представим для каждого пользователя релевантные айтемы, как последовательность слов. И будем предсказывать подходящие по смыслу слова.

# %%
data = data[['msno', 'song_id', 'target']]
data.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id  target
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       1
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=       1
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=       1
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=       1
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=       1

# %% [markdown]
# Закодируем все Id юзеров и песен и заменим на инлексы их айдишнки:

# %%
data = data.dropna()

users_arr = data["msno"].nunique()
songs_arr = data["song_id"].nunique()

user_to_idx = dict(zip(np.unique(data["msno"]), list(range(users_arr))))
song_to_idx = dict(zip(np.unique(data["song_id"]), list(range(songs_arr))))
idx_to_user = dict(zip(list(range(users_arr)), np.unique(data["msno"])))
idx_to_song = dict(zip(list(range(songs_arr)), np.unique(data["song_id"])))

data["msno"] = data["msno"].apply(lambda x: user_to_idx[x])
data["song_id"] = data["song_id"].apply(lambda x: song_to_idx[x])

data.head()
# Out:
#     msno  song_id  target
# 0   8158    74679       1
# 1  17259   223479       1
# 2  17259   120758       1
# 3  17259    23707       1
# 4   8158    33308       1

# %% [markdown]
# Теперь получиv train и test части:

# %%
data_train, data_test = train_test_split(data, test_size=0.2, shuffle=True)
data_train.shape, data_test.shape
# Out:
# ((5901934, 3), (1475484, 3))

# %% [markdown]
# Представим их в формате юзер: последовательность релевантных/нерелевантных айтемов.

# %%
data_train_relevant = data_train[data_train['target'] == 1].groupby('msno')['song_id'].apply(list).reset_index()
data_train_relevant = pd.DataFrame({'msno': data_train_relevant['msno'], 'relevant': data_train_relevant['song_id']})
data_train_relevant = data_train_relevant.sort_values(by='msno')

data_train_relevant.head()
# Out:
#    msno                                           relevant
# 0     0  [312530, 109275, 205905, 295587, 174513, 81189...
# 1     1  [215276, 336313, 319161, 158168, 119518, 17625...
# 2     2  [158356, 256953, 351749, 89514, 335402, 29948,...
# 3     3                                            [91646]
# 4     4  [132449, 56825, 140667, 275289, 146647, 26036,...

# %%
data_train_unrelevant = data_train[data_train['target'] == 0].groupby('msno')['song_id'].apply(list).reset_index()
data_train_unrelevant = pd.DataFrame({'msno': data_train_unrelevant['msno'], 'unrelevant': data_train_unrelevant['song_id']})
data_train_unrelevant = data_train_unrelevant.sort_values(by='msno')

data_train_unrelevant.head()
# Out:
#    msno                                         unrelevant
# 0     0  [206365, 349588, 357716, 294389, 249803, 10554...
# 1     1  [113756, 261188, 351616, 224523, 222716, 19963...
# 2     2  [213167, 231584, 12998, 154990, 230572, 283231...
# 3     3  [6483, 168333, 255003, 167303, 147886, 73313, ...
# 4     4  [44174, 182691, 359654, 195103, 95767, 245192,...

# %% [markdown]
# Также подготовим в test треки с положительным взаимодействием:

# %%
data_test = data_test[data_test['target'] == 1].groupby('msno')['song_id'].apply(list).reset_index()
data_test = pd.DataFrame({'msno': data_test['msno'], 'relevant': data_test['song_id']})
data_test = data_test.sort_values(by='msno')

data_test.head()
# Out:
#    msno                                           relevant
# 0     0  [130636, 175398, 359499, 269359, 339311, 32455...
# 1     1  [81614, 326162, 83292, 5174, 312782, 50398, 25...
# 2     2  [29697, 217320, 192060, 8218, 106432, 227529, ...
# 3     4  [6504, 225377, 5627, 339623, 313171, 332099, 8...
# 4     6  [30692, 154323, 194004, 222795, 316739, 146487...

# %% [markdown]
# Теперь создадим массив с положительными и отрицательными взаимодействиями:

# %%
song_groups = list(data_train_relevant['relevant']) + list(data_train_unrelevant['unrelevant'])
len(song_groups)
# Out:
# 56896

# %% [markdown]
# Загрузим модель. Вначале попробуем подавать позитивные и негативные сэмплы.

# %%
from gensim.models import Word2Vec
import datetime
import logging
logging.basicConfig()
logging.getLogger().setLevel(logging.INFO)

max_window = 99999999

start = datetime.datetime.now()
model = Word2Vec(song_groups, epochs=5, window=max_window, sg=1, min_count=10, hs=0, negative=5)
print("Time passed: " + str(datetime.datetime.now()-start))
# Out:
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 1103837 words, keeping 119045 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #20000, processed 2204439 words, keeping 171840 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #30000, processed 3287311 words, keeping 218805 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #40000, processed 4240874 words, keeping 264358 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #50000, processed 5220200 words, keeping 301808 word types
# INFO:gensim.models.word2vec:collected 324602 word types from a corpus of 5901934 raw words and 56896 sentences
# INFO:gensim.models.word2vec:Creating a fresh vocabulary
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=10 retains 53230 unique words (16.40% of original 324602, drops 271372)', 'datetime': '2024-05-01T10:24:30.410036', 'gensim': '4.3.2', 'python': '3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]', 'platform': 'Linux-6.1.58+-x86_64-with-glibc2.35', 'event': 'prepare_vocab'}
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=10 leaves 5294404 word corpus (89.71% of original 5901934, drops 607530)', 'datetime': '2024-05-01T10:24:30.426269', 'gensim': '4.3.2', 'python': '3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]', 'platform': 'Linux-6.1.58+-x86_64-with-glibc2.35', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 324602 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 0 most-common words
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 5294404 word corpus (100.0%% of prior 5294404)', 'datetime': '2024-05-01T10:24:30.671517', 'gensim': '4.3.2', 'python': '3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]', 'platform': 'Linux-6.1.58+-x86_64-with-glibc2.35', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:estimated required memory for 53230 words and 100 dimensions: 69199000 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.utils:Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-05-01T10:24:31.145386', 'gensim': '4.3.2', 'python': '3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]', 'platform': 'Linux-6.1.58+-x86_64-with-glibc2.35', 'event': 'build_vocab'}
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'training model with 3 workers on 53230 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=99999999 shrink_windows=True', 'datetime': '2024-05-01T10:24:31.146681', 'gensim': '4.3.2', 'python': '3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]', 'platform': 'Linux-6.1.58+-x86_64-with-glibc2.35', 'event': 'train'}
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 0.17% examples, 1022 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 0.32% examples, 1242 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 0.47% examples, 1758 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 0.65% examples, 1839 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 0.98% examples, 2559 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 1.13% examples, 2521 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 1.30% examples, 2508 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 1.45% examples, 2638 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 1.63% examples, 2322 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 1.91% examples, 2597 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 2.10% examples, 2713 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 2.27% examples, 2795 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 2.43% examples, 2826 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 2.60% examples, 2827 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 2.74% examples, 2782 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 2.92% examples, 2722 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 3.05% examples, 2698 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 3.22% examples, 2775 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 3.39% examples, 2850 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 3.57% examples, 2906 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 3.68% examples, 2775 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 3.84% examples, 2852 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 4.11% examples, 2694 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 4.39% examples, 2860 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 4.55% examples, 2800 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 4.93% examples, 2933 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 5.07% examples, 2824 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 5.35% examples, 2787 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 5.52% examples, 2833 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 5.83% examples, 2857 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 6.10% examples, 2945 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 6.25% examples, 2878 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 6.55% examples, 2978 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 6.73% examples, 2880 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 7.05% examples, 2986 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 7.22% examples, 2945 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 7.49% examples, 3029 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 7.65% examples, 2969 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 7.91% examples, 3002 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 8.10% examples, 2963 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 8.46% examples, 3028 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 8.61% examples, 3009 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 8.78% examples, 3017 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 8.95% examples, 3041 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 9.14% examples, 2981 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 9.31% examples, 2967 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 9.48% examples, 2994 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 9.64% examples, 2959 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 9.78% examples, 2955 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 9.92% examples, 2976 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 10.25% examples, 3017 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 10.39% examples, 3033 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 10.53% examples, 3006 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 10.70% examples, 3015 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 11.03% examples, 3013 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 11.20% examples, 3011 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 11.55% examples, 3055 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 11.68% examples, 3018 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 11.94% examples, 3032 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 12.10% examples, 2993 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 12.27% examples, 3008 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 12.45% examples, 3022 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 12.62% examples, 3002 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 12.79% examples, 3006 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 12.91% examples, 3015 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 13.06% examples, 3008 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 13.23% examples, 3017 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 13.39% examples, 3018 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 13.53% examples, 2990 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 13.81% examples, 2997 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 14.12% examples, 3023 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 14.27% examples, 3033 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 14.44% examples, 3041 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 14.59% examples, 2993 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 14.74% examples, 3007 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 14.88% examples, 3021 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 15.05% examples, 3008 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 15.54% examples, 3040 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 15.69% examples, 3055 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 15.86% examples, 3006 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 16.13% examples, 3001 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 16.29% examples, 3011 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 16.48% examples, 3010 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 16.66% examples, 3013 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 16.77% examples, 3019 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 16.92% examples, 3002 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 17.08% examples, 3012 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 17.26% examples, 2988 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 17.45% examples, 2998 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 17.73% examples, 3020 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 17.85% examples, 2998 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 18.15% examples, 3007 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 18.29% examples, 2978 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 18.42% examples, 2990 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 18.80% examples, 2998 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 19.09% examples, 3025 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 19.24% examples, 3015 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 19.40% examples, 3026 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 19.69% examples, 2989 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 19.84% examples, 2986 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 19.98% examples, 2995 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 20.15% examples, 2991 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 20.33% examples, 2965 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 20.49% examples, 2973 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 20.67% examples, 2956 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 20.86% examples, 2962 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 21.23% examples, 2970 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 21.72% examples, 2997 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 21.86% examples, 3009 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 22.23% examples, 2999 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 22.38% examples, 2986 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 22.55% examples, 2999 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 22.70% examples, 3007 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 22.87% examples, 2994 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 23.13% examples, 3028 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 23.30% examples, 3012 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 23.46% examples, 2999 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 23.61% examples, 3004 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 23.77% examples, 3001 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 23.89% examples, 3000 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 24.19% examples, 3023 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 24.35% examples, 3009 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 24.67% examples, 3029 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 24.83% examples, 3012 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 24.98% examples, 3019 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 25.09% examples, 3014 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 25.25% examples, 3020 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 25.58% examples, 3028 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 25.90% examples, 3054 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 26.07% examples, 3020 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 26.17% examples, 3028 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 26.33% examples, 3036 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 26.49% examples, 3028 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 26.64% examples, 3035 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 26.94% examples, 3037 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 27.07% examples, 3040 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 27.39% examples, 3014 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 27.85% examples, 3042 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 28.15% examples, 3043 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 28.63% examples, 3031 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 28.81% examples, 3042 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 28.94% examples, 3041 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 29.09% examples, 3040 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 29.40% examples, 3064 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 29.56% examples, 3052 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 29.75% examples, 3060 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 30.09% examples, 3047 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 30.27% examples, 3058 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 30.42% examples, 3060 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 30.59% examples, 3063 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 30.79% examples, 3070 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 30.92% examples, 3060 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 31.07% examples, 3068 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 31.21% examples, 3078 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 31.36% examples, 3057 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 31.56% examples, 3062 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 31.85% examples, 3025 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 32.32% examples, 3030 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 32.61% examples, 3024 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 32.78% examples, 3025 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 33.10% examples, 3037 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 33.26% examples, 3045 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 33.55% examples, 3044 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 33.68% examples, 3047 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 33.84% examples, 3038 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 34.02% examples, 3034 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 34.36% examples, 3049 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 34.54% examples, 3054 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 34.90% examples, 3069 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 35.07% examples, 3075 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 35.26% examples, 3082 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 35.42% examples, 3068 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 35.60% examples, 3067 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 35.91% examples, 3066 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 36.08% examples, 3075 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 36.38% examples, 3081 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 36.52% examples, 3088 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 36.65% examples, 3073 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 36.95% examples, 3083 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 37.13% examples, 3074 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 37.30% examples, 3078 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 37.41% examples, 3079 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 37.56% examples, 3082 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 37.80% examples, 3083 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 37.97% examples, 3084 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 38.13% examples, 3087 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 38.30% examples, 3083 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 38.50% examples, 3084 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 38.65% examples, 3076 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 38.83% examples, 3081 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 38.95% examples, 3086 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 39.09% examples, 3082 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 39.27% examples, 3077 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 39.41% examples, 3071 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 39.56% examples, 3078 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 39.72% examples, 3080 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 39.86% examples, 3083 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 40.25% examples, 3094 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 40.40% examples, 3086 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 40.54% examples, 3093 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 40.87% examples, 3077 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 41.34% examples, 3095 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 41.51% examples, 3098 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 41.63% examples, 3106 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 41.78% examples, 3110 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 41.95% examples, 3098 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 42.08% examples, 3100 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 42.25% examples, 3107 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 42.40% examples, 3096 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 42.54% examples, 3099 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 42.66% examples, 3101 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 42.84% examples, 3105 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 42.96% examples, 3108 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 43.11% examples, 3100 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 43.24% examples, 3104 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 43.38% examples, 3091 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 43.56% examples, 3093 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 43.68% examples, 3068 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 44.04% examples, 3085 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 44.21% examples, 3070 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 44.36% examples, 3072 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 44.69% examples, 3074 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 44.83% examples, 3066 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 44.99% examples, 3065 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 45.26% examples, 3074 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 45.43% examples, 3071 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 45.55% examples, 3070 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 45.69% examples, 3067 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 46.04% examples, 3066 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 46.18% examples, 3070 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 46.54% examples, 3073 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 46.79% examples, 3087 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 46.95% examples, 3070 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 47.25% examples, 3085 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 47.46% examples, 3075 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 47.66% examples, 3080 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 47.80% examples, 3080 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 47.97% examples, 3084 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 48.34% examples, 3094 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 48.52% examples, 3091 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 48.85% examples, 3088 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 49.04% examples, 3089 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 49.42% examples, 3089 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 49.73% examples, 3100 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 49.90% examples, 3094 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 50.45% examples, 3095 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 50.65% examples, 3098 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 50.77% examples, 3101 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 50.97% examples, 3102 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 51.10% examples, 3098 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 51.25% examples, 3102 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 51.59% examples, 3103 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 51.91% examples, 3109 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 52.09% examples, 3104 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 52.30% examples, 3107 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 52.52% examples, 3105 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 52.81% examples, 3108 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 53.15% examples, 3121 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 53.33% examples, 3116 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 53.51% examples, 3120 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 53.66% examples, 3120 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 53.84% examples, 3113 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 54.01% examples, 3112 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 54.15% examples, 3114 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 54.54% examples, 3125 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 54.74% examples, 3127 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 55.12% examples, 3135 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 55.30% examples, 3134 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 55.46% examples, 3138 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 55.65% examples, 3131 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 55.81% examples, 3129 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 55.98% examples, 3133 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 56.18% examples, 3137 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 56.40% examples, 3141 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 56.62% examples, 3141 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 56.82% examples, 3141 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 57.15% examples, 3142 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 57.33% examples, 3144 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 57.69% examples, 3138 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 57.87% examples, 3135 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 58.04% examples, 3138 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 58.24% examples, 3136 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 58.43% examples, 3135 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 58.74% examples, 3140 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 59.14% examples, 3153 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 59.35% examples, 3151 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 59.51% examples, 3154 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 59.71% examples, 3158 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 59.91% examples, 3152 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 60.09% examples, 3146 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 60.24% examples, 3147 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 60.39% examples, 3150 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 60.56% examples, 3153 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 60.75% examples, 3155 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 61.12% examples, 3159 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 61.33% examples, 3152 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 61.64% examples, 3149 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 61.89% examples, 3154 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 62.06% examples, 3156 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 62.27% examples, 3161 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 62.46% examples, 3164 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 62.66% examples, 3164 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 62.83% examples, 3164 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 63.15% examples, 3156 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 63.67% examples, 3159 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 64.24% examples, 3169 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 64.77% examples, 3174 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 65.11% examples, 3174 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 65.31% examples, 3171 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 65.49% examples, 3174 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 65.67% examples, 3177 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 65.84% examples, 3178 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 66.05% examples, 3182 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 66.48% examples, 3183 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 67.02% examples, 3188 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 67.34% examples, 3176 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 67.69% examples, 3186 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 67.90% examples, 3186 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 68.06% examples, 3189 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 68.43% examples, 3179 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 68.77% examples, 3190 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 68.97% examples, 3181 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 69.50% examples, 3190 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 69.79% examples, 3194 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 69.98% examples, 3193 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 70.42% examples, 3197 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 70.62% examples, 3194 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 70.99% examples, 3192 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 71.34% examples, 3202 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 71.51% examples, 3198 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 71.81% examples, 3209 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 71.98% examples, 3199 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 72.15% examples, 3201 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 72.34% examples, 3203 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 72.51% examples, 3196 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 72.83% examples, 3201 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 73.03% examples, 3201 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 73.18% examples, 3193 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 73.35% examples, 3184 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 73.68% examples, 3187 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 73.83% examples, 3178 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 74.18% examples, 3189 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 74.35% examples, 3187 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 74.72% examples, 3194 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 74.87% examples, 3196 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 75.05% examples, 3197 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 75.22% examples, 3189 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 75.38% examples, 3192 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 75.56% examples, 3194 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 75.77% examples, 3189 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 76.08% examples, 3200 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 76.25% examples, 3196 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 76.53% examples, 3202 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 76.73% examples, 3191 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 77.06% examples, 3199 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 77.23% examples, 3191 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 77.58% examples, 3192 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 77.85% examples, 3202 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 78.05% examples, 3198 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 78.24% examples, 3198 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 78.61% examples, 3199 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 78.80% examples, 3198 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 78.98% examples, 3195 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 79.51% examples, 3205 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 79.89% examples, 3211 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 80.07% examples, 3209 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 80.19% examples, 3207 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 80.35% examples, 3210 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 80.56% examples, 3206 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 80.77% examples, 3209 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 80.96% examples, 3213 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 81.18% examples, 3212 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 81.33% examples, 3214 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 81.71% examples, 3217 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 81.89% examples, 3215 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 82.06% examples, 3213 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 82.25% examples, 3216 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 82.42% examples, 3213 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 82.63% examples, 3216 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 82.99% examples, 3221 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 83.17% examples, 3223 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 83.55% examples, 3223 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 83.70% examples, 3223 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 83.84% examples, 3223 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 84.04% examples, 3224 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 84.21% examples, 3219 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 84.53% examples, 3227 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 84.70% examples, 3225 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 84.88% examples, 3229 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 85.05% examples, 3227 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 85.22% examples, 3230 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 85.43% examples, 3234 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 85.63% examples, 3230 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 85.80% examples, 3231 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 85.97% examples, 3229 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 86.16% examples, 3229 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 86.36% examples, 3229 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 86.76% examples, 3236 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 86.92% examples, 3235 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 87.36% examples, 3244 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 87.56% examples, 3238 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 87.73% examples, 3239 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 87.91% examples, 3241 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 88.09% examples, 3236 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 88.27% examples, 3238 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 88.43% examples, 3238 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 88.58% examples, 3229 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 88.79% examples, 3230 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 88.91% examples, 3222 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 89.09% examples, 3222 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 89.25% examples, 3224 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 89.38% examples, 3224 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 89.57% examples, 3227 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 89.74% examples, 3227 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 90.35% examples, 3232 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 90.51% examples, 3225 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 90.84% examples, 3228 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 91.05% examples, 3226 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 91.37% examples, 3233 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 91.55% examples, 3232 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 91.70% examples, 3233 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 92.06% examples, 3240 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 92.31% examples, 3234 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 92.47% examples, 3232 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 92.63% examples, 3234 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 92.83% examples, 3235 words/s, in_qsize 5, out_qsize 0
# ...
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 68.97% examples, 2865 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 69.27% examples, 2872 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 69.42% examples, 2870 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 69.79% examples, 2878 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 69.98% examples, 2868 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 70.42% examples, 2879 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 70.62% examples, 2873 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 70.99% examples, 2879 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 71.16% examples, 2880 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 71.34% examples, 2884 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 71.49% examples, 2879 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 71.66% examples, 2883 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 71.81% examples, 2884 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 71.98% examples, 2875 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 72.34% examples, 2882 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 72.50% examples, 2883 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 72.67% examples, 2886 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 72.83% examples, 2886 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 73.18% examples, 2879 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 73.35% examples, 2878 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 73.51% examples, 2880 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 73.68% examples, 2883 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 73.86% examples, 2880 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 74.18% examples, 2889 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 74.35% examples, 2888 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 74.53% examples, 2885 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 74.72% examples, 2887 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 74.87% examples, 2888 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 75.05% examples, 2885 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 75.22% examples, 2888 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 75.56% examples, 2892 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 75.77% examples, 2887 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 75.91% examples, 2890 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 76.08% examples, 2886 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 76.25% examples, 2882 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 76.37% examples, 2878 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 76.68% examples, 2878 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 76.85% examples, 2882 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 77.23% examples, 2883 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 77.38% examples, 2881 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 77.51% examples, 2875 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 77.85% examples, 2880 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 78.05% examples, 2882 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 78.22% examples, 2884 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 78.61% examples, 2890 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 78.80% examples, 2888 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 78.96% examples, 2881 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 79.14% examples, 2882 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 79.49% examples, 2886 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 79.89% examples, 2891 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 80.07% examples, 2894 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 80.19% examples, 2894 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 80.35% examples, 2896 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 80.56% examples, 2896 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 80.77% examples, 2891 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 80.96% examples, 2895 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 81.18% examples, 2893 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 81.33% examples, 2895 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 81.49% examples, 2897 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 81.71% examples, 2899 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 81.89% examples, 2897 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 82.06% examples, 2898 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 82.25% examples, 2901 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 82.42% examples, 2895 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 82.81% examples, 2904 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 83.00% examples, 2901 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 83.36% examples, 2909 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 83.52% examples, 2904 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 83.84% examples, 2903 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 84.04% examples, 2905 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 84.21% examples, 2904 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 84.37% examples, 2905 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 84.70% examples, 2911 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 84.88% examples, 2911 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 85.05% examples, 2909 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 85.22% examples, 2909 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 85.63% examples, 2911 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 85.80% examples, 2911 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 85.97% examples, 2913 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 86.16% examples, 2914 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 86.36% examples, 2913 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 86.56% examples, 2916 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 86.92% examples, 2916 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 87.36% examples, 2921 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 87.56% examples, 2917 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 87.73% examples, 2921 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 87.91% examples, 2922 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 88.09% examples, 2922 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 88.43% examples, 2928 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 88.58% examples, 2925 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 88.79% examples, 2925 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 88.91% examples, 2920 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 89.09% examples, 2921 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 89.25% examples, 2923 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 89.38% examples, 2924 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 89.74% examples, 2927 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 89.93% examples, 2929 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 90.35% examples, 2922 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 90.51% examples, 2914 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 90.65% examples, 2917 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 90.84% examples, 2916 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 91.05% examples, 2917 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 91.21% examples, 2920 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 91.37% examples, 2922 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 91.55% examples, 2922 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 91.70% examples, 2922 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 91.84% examples, 2925 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 92.06% examples, 2926 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 92.31% examples, 2922 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 92.47% examples, 2919 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 92.83% examples, 2927 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 93.01% examples, 2926 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 93.15% examples, 2929 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 93.30% examples, 2928 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 93.45% examples, 2928 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 93.63% examples, 2930 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 93.78% examples, 2921 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 94.09% examples, 2926 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 94.22% examples, 2925 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 94.58% examples, 2931 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 94.76% examples, 2930 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 94.93% examples, 2930 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 95.13% examples, 2923 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 95.28% examples, 2925 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 95.58% examples, 2926 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 95.92% examples, 2934 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 96.11% examples, 2931 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 96.36% examples, 2934 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 96.56% examples, 2935 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 96.73% examples, 2928 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 96.91% examples, 2929 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 97.31% examples, 2936 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 97.47% examples, 2932 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 98.05% examples, 2934 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 98.22% examples, 2936 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 98.39% examples, 2936 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 98.59% examples, 2934 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 98.76% examples, 2937 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 99.11% examples, 2940 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 99.28% examples, 2942 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 99.49% examples, 2936 words/s, in_qsize 4, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 99.80% examples, 2942 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 100.00% examples, 2944 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.word2vec:EPOCH 4: training on 5901934 raw words (5294404 effective words) took 1798.6s, 2944 effective words/s
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'training on 29509670 raw words (26472020 effective words) took 8562.7s, 3092 effective words/s', 'datetime': '2024-05-01T12:47:13.864195', 'gensim': '4.3.2', 'python': '3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]', 'platform': 'Linux-6.1.58+-x86_64-with-glibc2.35', 'event': 'train'}
# INFO:gensim.utils:Word2Vec lifecycle event {'params': 'Word2Vec<vocab=53230, vector_size=100, alpha=0.025>', 'datetime': '2024-05-01T12:47:13.865273', 'gensim': '4.3.2', 'python': '3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]', 'platform': 'Linux-6.1.58+-x86_64-with-glibc2.35', 'event': 'created'}
# Time passed: 2:22:44.904501

# %% [markdown]
# Сохраним обученную модель:

# %%
model.save('item2vec_pos_and_neg_samples.model')
# Out:
# INFO:gensim.utils:Word2Vec lifecycle event {'fname_or_handle': 'item2vec_pos_and_neg_samples.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-05-01T12:48:17.403335', 'gensim': '4.3.2', 'python': '3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]', 'platform': 'Linux-6.1.58+-x86_64-with-glibc2.35', 'event': 'saving'}
# INFO:gensim.utils:not storing attribute cum_table
# INFO:gensim.utils:saved item2vec_pos_and_neg_samples.model

# %% [markdown]
# Определим метрику:

# %%
def calc_ndcg(recomendations, relevant, k=20):
    if len(recomendations) < len(relevant):
        recomendations = np.concatenate((recomendations, np.zeros(len(relevant) - len(recomendations))))
    if len(relevant) < len(recomendations):
        relevant = np.concatenate((relevant, np.zeros(len(recomendations) - len(relevant))))

    return ndcg_score([relevant], [recomendations], k = 20)

# %% [markdown]
# Построим рекомендации. Для этого возьмем каждый релевантный для пользователя трек и вернем похожие на него треки.

# %%
def recommend_for_user(user_idx, model_emb, train, N_neighb=20):
    if not(user_idx in train['msno'].values):
        return np.asarray([])

    train_relevant = train[train['msno'] == user_idx]['relevant']
    if train_relevant.empty:
        return np.asarray([])

    recommendations = {}
    for song_idx in train_relevant.iloc[0]:
        if song_idx in model.wv.key_to_index.keys():
            nearest_for_song = model_emb.wv.most_similar(positive=[song_idx], topn=20)
            for ind, dist in nearest_for_song:
                if ind not in recommendations or recommendations[ind] > dist:
                    recommendations[ind] = dist

    sorted_recommendations = sorted(recommendations.items(), key=lambda x: x[1])
    top_recommendations = dict(sorted_recommendations[:N_neighb])

    return np.asarray(list(top_recommendations.keys()))

# %%
def predict_for_all_users(users, train, model_emb):
    ncdg_values = np.asarray([])

    for index, row in users.iterrows():
        user_idx = int(row['msno'])
        recomendations = recommend_for_user(user_idx, model_emb, train)
        relevant = np.asarray(row['relevant'])

        if (len(relevant) != 0) and (len(recomendations) != 0):
            ndcg_user = calc_ndcg(recomendations, relevant, 20)
            ncdg_values = np.concatenate((ncdg_values, np.asarray([ndcg_user])))

    return ncdg_values

# %% [markdown]
# Посмотрим на результат. Так как подсчет на всез пользователях будет занимать примерно 5 часов на T4 GPU, то возьмем случаную выборку и протестируем на ней:

# %%
ncdg_values = predict_for_all_users(data_test.sample(2400), data_train_relevant, model)

print('max ndcg@20 score: ', ncdg_values.max())
print('min ndcg@20 score: ', ncdg_values.min())
print('mean ndcg@20 score: ', ncdg_values.sum()/len(ncdg_values))
# Out:
# max ndcg@20 score:  1.0
# min ndcg@20 score:  0.2276702486969526
# mean ndcg@20 score:  0.5935382149986984

# %% [markdown]
# Это лишний раз подтверждает предположние, что допольнительная информация о треках и пользователях помогает значительно увеличить метрику NDCG@20. Так как в этом случае скор сопоставимый с остальными методами, которые используют только информацию положительных и негативных взаимодействий.
#
# также приложу таблицу сравнений усредненных по юзерам значений NDCG@20(остальные модели во втором ноутбуке):
#
#
# | model_name    | XGBRanker | kNN (cosine) | kNN (euclidean) | Implicit ALS | Word2Vec + cossim |
# |---------------|-----------|--------------|-----------------|--------------|-------------------|
# | NDCG@20 score | 0.8203    | 0.6157       | 0.6545          | 0.5715       | 0.5935            |
